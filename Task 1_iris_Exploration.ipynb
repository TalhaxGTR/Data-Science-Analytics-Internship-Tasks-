# %% [markdown]
# #Task 1

# %% [markdown]
# #Load Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #load iris datasetb

# %%
iris = sns.load_dataset('iris')
print(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #check shape (rows , columns)

# %%
print("shape of Dataset: ", iris.shape)
# Out:
# shape of Dataset:  (150, 5)

# %% [markdown]
# #check column names

# %%
print('Columns names : ', iris.columns)
# Out:
# Columns names :  Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# #Display first 5 rows

# %%
print('First five rows :', iris.head())
# Out:
# First five rows :    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# #Create Visualizations
# #Scatter Plot

# %%
sns.scatterplot(data=iris, x='petal_length', y='petal_width', hue='species')
plt.title('petal length vs petal width')
plt.show()

# %% [markdown]
# #histogram Plot

# %%
sns.histplot(data=iris, x='sepal_length', kde=True)
plt.title('Distribution of Sepal Length')
plt.show()

# %% [markdown]
# #Box Plot

# %%
sns.boxplot(data=iris, x='species', y='sepal_length')
plt.title("Box plot of sepal length by species")
plt.show()
